# %%
import scipy as sp
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %%
# 한글 폰트 사용을 위해서 세팅
from matplotlib import font_manager, rc
font_path = "C:/Windows/Fonts/malgun.ttf"
font = font_manager.FontProperties(fname=font_path).get_name()
rc('font', family=font)

# %%
N= 50
p = 0.3
l = N * p
poisson = sp.stats.poisson(l)
xx = np.arange(N+1)
plt.bar(xx, poisson.pmf(xx), align="center")
# Out:
# <BarContainer object of 51 artists>

# %%
def plot_poisson_distribution(l):
    poisson = sp.stats.poisson(l)
    xx = np.arange(N + 1)
    plt.plot(xx, poisson.pmf(xx),'o--', label = r'$(\lambda =$' + str(l) + ')')
    plt.xlabel("표본값")
    plt.ylabel("$P(x)$")
    plt.title("푸아송의 확률질량함수")
    plt.grid()
    plt.legend()

# %%
plt.figure(figsize=(12,8))
xx = np.arange(40)
for l in range(4,30,4):
    poisson = sp.stats.poisson(l)
    plt.plot(xx, poisson.pmf(xx),'o--', label = r'$(\lambda =$' + str(l) + ')')

plt.xlabel("표본값")
plt.ylabel("$P(x)$")
plt.title("푸아송의 확률질량함수")
plt.grid()
plt.legend() 
plt.show()
