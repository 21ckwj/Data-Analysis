# %%
import numpy as np
import scipy as sp
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")
sns.set_context("notebook")

# %%
# 한글 폰트 사용을 위해서 세팅
from matplotlib import font_manager, rc
font_path = "C:/Windows/Fonts/malgun.ttf"
font = font_manager.FontProperties(fname=font_path).get_name()
rc('font', family=font)

# %%
## scipy 모듈 그래프 반대로 나옴

plt.figure(figsize=(10,6))
loc = 0
xx = np.linspace(0, 10, 101)
lambdas = [0.5,1,2,4,8]
for l in lambdas:
    rv = sp.stats.expon(loc,l)
    plt.plot(xx, rv.pdf(xx),linewidth=2, label = r'$(\lambda =$' + str(l) + ')')

plt.xlabel("표본값")
plt.ylabel("$P(x)$")
plt.title("지수분포의 확률밀도함수")
plt.grid()
plt.legend() 
plt.show()

# %%
np.random.exponential(0.5)
# Out:
# 0.02951901754757478

# %%
## numpy 로 직접 계산

plt.figure(figsize=(10,6))
loc = 0
xx = np.linspace(0, 3, 100)
lambdas = [0.5,1,2,3]
for l in lambdas:
    pdf_values = l * np.exp(-l*xx)
    plt.plot(xx, pdf_values,linewidth=2 ,label = r'$(\lambda =$' + str(l) + ')')

plt.xlabel("표본값")
plt.ylabel("$P(x)$")
plt.title("지수분포의 확률밀도함수")
plt.grid()
plt.legend() 
plt.show()
