# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from statsmodels.graphics.tsaplots import plot_acf

N_lags = 30
rand_data = np.random.rand(100)
plt.figure(figsize=(10,4))
plot_acf(rand_data,lags=N_lags, alpha=0.05)
plt.xlabel(f'Lag at 0 to {N_lags}')
plt.ylabel("lag at k's autocorrelation")
plt.show()

# %%
rand

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from statsmodels.graphics.tsaplots import plot_acf

N_lags = 30
# 정규분포 데이터
rand_data = np.random.normal(0,1,100)
plt.figure(figsize=(10,4))
plot_acf(rand_data,lags=N_lags, alpha=0.05)
plt.xlabel(f'Lag at 0 to {N_lags}')
plt.ylabel("lag at k's autocorrelation")
plt.show()

# %%
plt.plot(range(0,100), rand_data)

# %%
 # trend

# %%
# seasonality

# %%
df = pd.read_csv('../lazy_timeseries/airline_passengers.csv')
df.plot()
# Out:
# <AxesSubplot:>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from statsmodels.graphics.tsaplots import plot_acf

N_lags = 30
# 계절성 + 추세
data = df['Passengers']
plt.figure(figsize=(10,4))
plot_acf(data,lags=N_lags, alpha=0.05)
plt.xlabel(f'Lag at 0 to {N_lags}')
plt.ylabel("lag at k's autocorrelation")
plt.show()
