# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
df_train = pd.read_csv('../data/따릉이/train.csv')
df_train
# Out:
#         id  hour  hour_bef_temperature  hour_bef_precipitation  \
# 0        3    20                  16.3                     1.0
# 1        6    13                  20.1                     0.0
# 2        7     6                  13.9                     0.0
# 3        8    23                   8.1                     0.0
# 4        9    18                  29.5                     0.0
# ...    ...   ...                   ...                     ...
# 1454  2174     4                  16.8                     0.0
# 1455  2175     3                  10.8                     0.0
# 1456  2176     5                  18.3                     0.0
# 1457  2178    21                  20.7                     0.0
# 1458  2179    17                  21.1                     0.0
#
#       hour_bef_windspeed  hour_bef_humidity  hour_bef_visibility  \
# 0                    1.5               89.0                576.0
# 1                    1.4               48.0                916.0
# 2                    0.7               79.0               1382.0
# 3                    2.7               54.0                946.0
# 4                    4.8                7.0               2000.0
# ...                  ...                ...                  ...
# 1454                 1.6               53.0               2000.0
# 1455                 3.8               45.0               2000.0
# 1456                 1.9               54.0               2000.0
# 1457                 3.7               37.0               1395.0
# 1458                 3.1               47.0               1973.0
#
#       hour_bef_ozone  hour_bef_pm10  hour_bef_pm2.5  count
# 0              0.027           76.0            33.0   49.0
# 1              0.042           73.0            40.0  159.0
# 2              0.033           32.0            19.0   26.0
# 3              0.040           75.0            64.0   57.0
# 4              0.057           27.0            11.0  431.0
# ...              ...            ...             ...    ...
# 1454           0.031           37.0            27.0   21.0
# 1455           0.039           34.0            19.0   20.0
# 1456           0.009           30.0            21.0   22.0
# 1457           0.082           71.0            36.0  216.0
# 1458           0.046           38.0            17.0  170.0
#
# [1459 rows x 11 columns]

# %%
df_train.isnull().sum()
# Out:
# id                          0
# hour                        0
# hour_bef_temperature        2
# hour_bef_precipitation      2
# hour_bef_windspeed          9
# hour_bef_humidity           2
# hour_bef_visibility         2
# hour_bef_ozone             76
# hour_bef_pm10              90
# hour_bef_pm2.5            117
# count                       0
# dtype: int64

# %%
df_test = pd.read_csv('../data/따릉이/test.csv')
df_test
# Out:
#        id  hour  hour_bef_temperature  hour_bef_precipitation  \
# 0       0     7                  20.7                     0.0
# 1       1    17                  30.0                     0.0
# 2       2    13                  19.0                     1.0
# 3       4     6                  22.5                     0.0
# 4       5    22                  14.6                     1.0
# ..    ...   ...                   ...                     ...
# 710  2148     1                  24.6                     0.0
# 711  2149     1                  18.1                     0.0
# 712  2165     9                  23.3                     0.0
# 713  2166    16                  27.0                     0.0
# 714  2177     8                  22.3                     0.0
#
#      hour_bef_windspeed  hour_bef_humidity  hour_bef_visibility  \
# 0                   1.3               62.0                954.0
# 1                   5.4               33.0               1590.0
# 2                   2.1               95.0                193.0
# 3                   2.5               60.0               1185.0
# 4                   3.4               93.0                218.0
# ..                  ...                ...                  ...
# 710                 2.4               60.0               1745.0
# 711                 1.0               55.0               2000.0
# 712                 2.3               66.0               1789.0
# 713                 1.6               46.0               1956.0
# 714                 1.0               63.0               1277.0
#
#      hour_bef_ozone  hour_bef_pm10  hour_bef_pm2.5
# 0             0.041           44.0            27.0
# 1             0.061           49.0            36.0
# 2             0.020           36.0            28.0
# 3             0.027           52.0            38.0
# 4             0.041           18.0            15.0
# ..              ...            ...             ...
# 710             NaN            NaN             NaN
# 711             NaN            NaN             NaN
# 712           0.020           17.0            15.0
# 713           0.032           40.0            26.0
# 714           0.007           30.0            24.0
#
# [715 rows x 10 columns]

# %%
df_test.isnull().sum()
# Out:
# id                         0
# hour                       0
# hour_bef_temperature       1
# hour_bef_precipitation     1
# hour_bef_windspeed         1
# hour_bef_humidity          1
# hour_bef_visibility        1
# hour_bef_ozone            35
# hour_bef_pm10             37
# hour_bef_pm2.5            36
# dtype: int64

# %% [markdown]
# # preprocessing

# %%
df_bike = pd.concat([df_train.iloc[:,:-1],df_test], axis=0)
df_bike
# Out:
#        id  hour  hour_bef_temperature  hour_bef_precipitation  \
# 0       3    20                  16.3                     1.0
# 1       6    13                  20.1                     0.0
# 2       7     6                  13.9                     0.0
# 3       8    23                   8.1                     0.0
# 4       9    18                  29.5                     0.0
# ..    ...   ...                   ...                     ...
# 710  2148     1                  24.6                     0.0
# 711  2149     1                  18.1                     0.0
# 712  2165     9                  23.3                     0.0
# 713  2166    16                  27.0                     0.0
# 714  2177     8                  22.3                     0.0
#
#      hour_bef_windspeed  hour_bef_humidity  hour_bef_visibility  \
# 0                   1.5               89.0                576.0
# 1                   1.4               48.0                916.0
# 2                   0.7               79.0               1382.0
# 3                   2.7               54.0                946.0
# 4                   4.8                7.0               2000.0
# ..                  ...                ...                  ...
# 710                 2.4               60.0               1745.0
# 711                 1.0               55.0               2000.0
# 712                 2.3               66.0               1789.0
# 713                 1.6               46.0               1956.0
# 714                 1.0               63.0               1277.0
#
#      hour_bef_ozone  hour_bef_pm10  hour_bef_pm2.5
# 0             0.027           76.0            33.0
# 1             0.042           73.0            40.0
# 2             0.033           32.0            19.0
# 3             0.040           75.0            64.0
# 4             0.057           27.0            11.0
# ..              ...            ...             ...
# 710             NaN            NaN             NaN
# 711             NaN            NaN             NaN
# 712           0.020           17.0            15.0
# 713           0.032           40.0            26.0
# 714           0.007           30.0            24.0
#
# [2174 rows x 10 columns]

# %%
df_bike.duplicated().sum()
# Out:
# 0

# %% [markdown]
# # Nan값 파악

# %%
df_bike.isnull().sum()
# Out:
# id                          0
# hour                        0
# hour_bef_temperature        3
# hour_bef_precipitation      3
# hour_bef_windspeed         10
# hour_bef_humidity           3
# hour_bef_visibility         3
# hour_bef_ozone            111
# hour_bef_pm10             127
# hour_bef_pm2.5            153
# dtype: int64

# %%
df_bike[df_bike['hour_bef_temperature'].isnull()]
# Out:
#         id  hour  hour_bef_temperature  hour_bef_precipitation  \
# 934   1420     0                   NaN                     NaN
# 1035  1553    18                   NaN                     NaN
# 653   1943    19                   NaN                     NaN
#
#       hour_bef_windspeed  hour_bef_humidity  hour_bef_visibility  \
# 934                  NaN                NaN                  NaN
# 1035                 NaN                NaN                  NaN
# 653                  NaN                NaN                  NaN
#
#       hour_bef_ozone  hour_bef_pm10  hour_bef_pm2.5
# 934              NaN            NaN             NaN
# 1035             NaN            NaN             NaN
# 653              NaN            NaN             NaN

# %%
idx = df_bike[df_bike['hour_bef_temperature'].isnull()].index
idx
df_bike = df_bike.drop(index = idx)
df_bike
# Out:
#        id  hour  hour_bef_temperature  hour_bef_precipitation  \
# 0       3    20                  16.3                     1.0
# 1       6    13                  20.1                     0.0
# 2       7     6                  13.9                     0.0
# 3       8    23                   8.1                     0.0
# 4       9    18                  29.5                     0.0
# ..    ...   ...                   ...                     ...
# 710  2148     1                  24.6                     0.0
# 711  2149     1                  18.1                     0.0
# 712  2165     9                  23.3                     0.0
# 713  2166    16                  27.0                     0.0
# 714  2177     8                  22.3                     0.0
#
#      hour_bef_windspeed  hour_bef_humidity  hour_bef_visibility  \
# 0                   1.5               89.0                576.0
# 1                   1.4               48.0                916.0
# 2                   0.7               79.0               1382.0
# 3                   2.7               54.0                946.0
# 4                   4.8                7.0               2000.0
# ..                  ...                ...                  ...
# 710                 2.4               60.0               1745.0
# 711                 1.0               55.0               2000.0
# 712                 2.3               66.0               1789.0
# 713                 1.6               46.0               1956.0
# 714                 1.0               63.0               1277.0
#
#      hour_bef_ozone  hour_bef_pm10  hour_bef_pm2.5
# 0             0.027           76.0            33.0
# 1             0.042           73.0            40.0
# 2             0.033           32.0            19.0
# 3             0.040           75.0            64.0
# 4             0.057           27.0            11.0
# ..              ...            ...             ...
# 710             NaN            NaN             NaN
# 711             NaN            NaN             NaN
# 712           0.020           17.0            15.0
# 713           0.032           40.0            26.0
# 714           0.007           30.0            24.0
#
# [2170 rows x 10 columns]

# %%
df_bike.isnull().sum()
# Out:
# id                          0
# hour                        0
# hour_bef_temperature        0
# hour_bef_precipitation      0
# hour_bef_windspeed          7
# hour_bef_humidity           0
# hour_bef_visibility         0
# hour_bef_ozone            108
# hour_bef_pm10             124
# hour_bef_pm2.5            150
# dtype: int64

# %% [markdown]
# ## 데이터 살펴보기

# %%
for col in df_bike.columns[2:]:
    plt.figure(figsize=(5,3))
    sns.distplot(df_bike[col], bins=50 )

# %%
# hour_bef_visibilty 2000 이상치 확인필요
# 2000 이 제일 맑은 최대치
df_bike[df_bike['hour_bef_visibility']==2000]
# Out:
#        id  hour  hour_bef_temperature  hour_bef_precipitation  \
# 4       9    18                  29.5                     0.0
# 14     28     1                  20.0                     0.0
# 16     30    21                  18.8                     0.0
# 22     37    16                  19.4                     0.0
# 28     48    15                  18.0                     0.0
# ..    ...   ...                   ...                     ...
# 701  2127    17                  29.6                     0.0
# 703  2134    18                  29.2                     0.0
# 705  2141    17                  27.8                     0.0
# 708  2146     3                  21.6                     0.0
# 711  2149     1                  18.1                     0.0
#
#      hour_bef_windspeed  hour_bef_humidity  hour_bef_visibility  \
# 4                   4.8                7.0               2000.0
# 14                  1.8               58.0               2000.0
# 16                  2.2               34.0               2000.0
# 22                  5.9               21.0               2000.0
# 28                  3.3               20.0               2000.0
# ..                  ...                ...                  ...
# 701                 2.5               19.0               2000.0
# 703                 3.1               23.0               2000.0
# 705                 1.5               27.0               2000.0
# 708                 2.6               41.0               2000.0
# 711                 1.0               55.0               2000.0
#
#      hour_bef_ozone  hour_bef_pm10  hour_bef_pm2.5
# 4             0.057           27.0            11.0
# 14              NaN            NaN             NaN
# 16            0.040           32.0            14.0
# 22            0.052           52.0            14.0
# 28            0.045           54.0            21.0
# ..              ...            ...             ...
# 701           0.081           23.0            18.0
# 703           0.058           26.0            11.0
# 705           0.068           27.0            17.0
# 708           0.044           25.0            16.0
# 711             NaN            NaN             NaN
#
# [536 rows x 10 columns]

# %%
for col in df_bike.columns[2:]:
    plt.figure(figsize=(5,3))
    sns.boxplot(df_bike, x='hour', y=col)

# %% [markdown]
#  ## Nan 값 : 시간, 강수 유무에 따라 채우기

# %%
df_bike[df_bike['hour_bef_precipitation']==1].isnull().sum()
# Out:
# id                        0
# hour                      0
# hour_bef_temperature      0
# hour_bef_precipitation    0
# hour_bef_windspeed        0
# hour_bef_humidity         0
# hour_bef_visibility       0
# hour_bef_ozone            5
# hour_bef_pm10             7
# hour_bef_pm2.5            8
# dtype: int64

# %%
col = ['id','hour', 'hour_bef_ozone', 'hour_bef_pm10', 'hour_bef_pm2.5'] 
df_bike[df_bike['hour_bef_precipitation']==1][col].sort_values(by='hour').plot(figsize=(8,5),subplots=True)
# Out:
# array([<AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>,
#        <AxesSubplot:>], dtype=object)

# %%
col = ['id','hour', 'hour_bef_ozone', 'hour_bef_pm10', 'hour_bef_pm2.5'] 
df_bike[df_bike['hour_bef_precipitation']==1].sort_values(by='hour')[col][:30]
# Out:
#         id  hour  hour_bef_ozone  hour_bef_pm10  hour_bef_pm2.5
# 288    825     0           0.036           12.0            11.0
# 154    230     0           0.012           69.0            59.0
# 40     115     1             NaN            NaN             NaN
# 507    782     1             NaN            NaN             NaN
# 102    297     1             NaN            NaN             NaN
# 796   1214     1             NaN            NaN             NaN
# 222    346     1             NaN            NaN             NaN
# 1245  1882     2           0.034            9.0             8.0
# 1443  2161     2           0.017           67.0            57.0
# 299    861     2           0.036            9.0             9.0
# 984   1485     2           0.004           29.0            26.0
# 447   1318     2           0.013           31.0            22.0
# 363    554     3           0.010           68.0            57.0
# 400   1166     3           0.037            9.0             9.0
# 130    194     3           0.032          103.0            23.0
# 1109  1673     4           0.040           24.0            24.0
# 155    435     4           0.036            9.0             9.0
# 59      93     5           0.026           35.0            24.0
# 157    441     5           0.036           25.0            21.0
# 627   1872     6           0.068           81.0            54.0
# 636    974     6           0.020           59.0            31.0
# 477   1409     6           0.034           10.0             8.0
# 295    853     6           0.031           24.0            21.0
# 46     143     7           0.031           24.0            17.0
# 493   1467     7           0.031           11.0            12.0
# 495    762     7           0.019           58.0            29.0
# 352   1031     7           0.057           80.0            55.0
# 539    831     8           0.029           26.0            24.0
# 9       17     8           0.022           12.0            12.0
# 606   1818     8           0.049           42.0            32.0

# %% [markdown]
# ## hour_bef_ozone

# %%
df_bike[df_bike['hour_bef_ozone'].isnull()].sort_values(by='hour')
# Out:
#         id  hour  hour_bef_temperature  hour_bef_precipitation  \
# 14      28     1                  20.0                     0.0
# 40     115     1                  21.5                     1.0
# 32      82     1                  22.8                     0.0
# 1391  2086     1                  11.5                     0.0
# 1361  2047     1                  12.6                     0.0
# ...    ...   ...                   ...                     ...
# 1211  1829    16                  23.0                     0.0
# 122    181    16                  26.2                     0.0
# 451    695    17                  20.1                     0.0
# 44      76    17                  21.7                     0.0
# 422    654    18                  20.3                     0.0
#
#       hour_bef_windspeed  hour_bef_humidity  hour_bef_visibility  \
# 14                   1.8               58.0               2000.0
# 40                   0.5               90.0                347.0
# 32                   2.4               52.0               2000.0
# 1391                 3.2               23.0               2000.0
# 1361                 2.4               48.0               1805.0
# ...                  ...                ...                  ...
# 1211                 2.9               26.0               2000.0
# 122                  4.3               31.0               1718.0
# 451                  4.5               25.0               2000.0
# 44                   3.0               35.0               2000.0
# 422                  4.1               24.0               2000.0
#
#       hour_bef_ozone  hour_bef_pm10  hour_bef_pm2.5
# 14               NaN            NaN             NaN
# 40               NaN            NaN             NaN
# 32               NaN            NaN             NaN
# 1391             NaN            NaN             NaN
# 1361             NaN            NaN             NaN
# ...              ...            ...             ...
# 1211             NaN           22.0             8.0
# 122              NaN           47.0            23.0
# 451              NaN           58.0            29.0
# 44               NaN           32.0            19.0
# 422              NaN           57.0            27.0
#
# [108 rows x 10 columns]

# %%
fig, axs = plt.subplots(ncols=2,nrows=1, figsize=(10,3))
sns.boxplot(df_bike[df_bike['hour_bef_precipitation']==0].sort_values(by='hour'), x='hour', y='hour_bef_ozone',ax=axs[0])
sns.boxplot(df_bike[df_bike['hour_bef_precipitation']==1].sort_values(by='hour'), x='hour', y='hour_bef_ozone',ax=axs[1])
# Out:
# <AxesSubplot:xlabel='hour', ylabel='hour_bef_ozone'>

# %% [markdown]
# ## 미세먼지 hour_bef_pm2.5
# * 비 안 온날은 비슷
# * 비 온날은 불규칙

# %%
fig, axs = plt.subplots(ncols=2,nrows=1, figsize=(10,3))
sns.boxplot(df_bike[df_bike['hour_bef_precipitation']==0].sort_values(by='hour'), x='hour', y='hour_bef_pm2.5',ax=axs[0])
sns.boxplot(df_bike[df_bike['hour_bef_precipitation']==1].sort_values(by='hour'), x='hour', y='hour_bef_pm2.5',ax=axs[1])
# Out:
# <AxesSubplot:xlabel='hour', ylabel='hour_bef_pm2.5'>

# %% [markdown]
# ## 미세먼지 hour_bef_pm10
# * 비 안 온날은 비슷
# * 비 온날은 불규칙

# %%
fig, axs = plt.subplots(ncols=2,nrows=1, figsize=(10,3))
sns.boxplot(df_bike[df_bike['hour_bef_precipitation']==0].sort_values(by='hour'), x='hour', y='hour_bef_pm10',ax=axs[0])
sns.boxplot(df_bike[df_bike['hour_bef_precipitation']==1].sort_values(by='hour'), x='hour', y='hour_bef_pm10',ax=axs[1])
# Out:
# <AxesSubplot:xlabel='hour', ylabel='hour_bef_pm10'>

# %% [markdown]
# ## hour_bef_windspeed

# %%
fig, axs = plt.subplots(ncols=2,nrows=1, figsize=(10,3))
sns.boxplot(df_bike[df_bike['hour_bef_precipitation']==0].sort_values(by='hour'), x='hour', y='hour_bef_windspeed',ax=axs[0])
sns.boxplot(df_bike[df_bike['hour_bef_precipitation']==1].sort_values(by='hour'), x='hour', y='hour_bef_windspeed',ax=axs[1])
# Out:
# <AxesSubplot:xlabel='hour', ylabel='hour_bef_windspeed'>

# %% [markdown]
# # Nan값 채우기

# %%
df_bike = pd.concat([df_train.iloc[:,:-1],df_test], axis=0)
idx = df_bike[df_bike['hour_bef_temperature'].isnull()].index
df_bike = df_bike.drop(index = idx)
df_bike = df_bike.reset_index(drop=True)
df_bike
# Out:
#         id  hour  hour_bef_temperature  hour_bef_precipitation  \
# 0        3    20                  16.3                     1.0
# 1        6    13                  20.1                     0.0
# 2        7     6                  13.9                     0.0
# 3        8    23                   8.1                     0.0
# 4        9    18                  29.5                     0.0
# ...    ...   ...                   ...                     ...
# 2165  2148     1                  24.6                     0.0
# 2166  2149     1                  18.1                     0.0
# 2167  2165     9                  23.3                     0.0
# 2168  2166    16                  27.0                     0.0
# 2169  2177     8                  22.3                     0.0
#
#       hour_bef_windspeed  hour_bef_humidity  hour_bef_visibility  \
# 0                    1.5               89.0                576.0
# 1                    1.4               48.0                916.0
# 2                    0.7               79.0               1382.0
# 3                    2.7               54.0                946.0
# 4                    4.8                7.0               2000.0
# ...                  ...                ...                  ...
# 2165                 2.4               60.0               1745.0
# 2166                 1.0               55.0               2000.0
# 2167                 2.3               66.0               1789.0
# 2168                 1.6               46.0               1956.0
# 2169                 1.0               63.0               1277.0
#
#       hour_bef_ozone  hour_bef_pm10  hour_bef_pm2.5
# 0              0.027           76.0            33.0
# 1              0.042           73.0            40.0
# 2              0.033           32.0            19.0
# 3              0.040           75.0            64.0
# 4              0.057           27.0            11.0
# ...              ...            ...             ...
# 2165             NaN            NaN             NaN
# 2166             NaN            NaN             NaN
# 2167           0.020           17.0            15.0
# 2168           0.032           40.0            26.0
# 2169           0.007           30.0            24.0
#
# [2170 rows x 10 columns]

# %%
df_bike.isnull().sum()
# Out:
# id                          0
# hour                        0
# hour_bef_temperature        0
# hour_bef_precipitation      0
# hour_bef_windspeed          7
# hour_bef_humidity           0
# hour_bef_visibility         0
# hour_bef_ozone            108
# hour_bef_pm10             124
# hour_bef_pm2.5            150
# dtype: int64

# %% [markdown]
# ## hour_bef_ozone

# %%
# 0시 강수 없는날
df_bike[(df_bike['hour_bef_precipitation']==0) &  (df_bike['hour']==0)]
# Out:
#         id  hour  hour_bef_temperature  hour_bef_precipitation  \
# 25      45     0                  11.7                     0.0
# 80     126     0                  15.5                     0.0
# 124    183     0                  18.5                     0.0
# 149    223     0                  18.6                     0.0
# 167    249     0                  16.6                     0.0
# ...    ...   ...                   ...                     ...
# 2087  1885     0                  18.7                     0.0
# 2094  1900     0                  21.7                     0.0
# 2118  1976     0                  20.2                     0.0
# 2124  2004     0                  21.5                     0.0
# 2162  2145     0                  20.0                     0.0
#
#       hour_bef_windspeed  hour_bef_humidity  hour_bef_visibility  \
# 25                   3.5               80.0                895.0
# 80                   0.9               30.0               2000.0
# 124                  0.9               46.0               1848.0
# 149                  0.3               58.0                554.0
# 167                  2.3               47.0               1048.0
# ...                  ...                ...                  ...
# 2087                 0.8               60.0               2000.0
# 2094                 4.3               40.0               2000.0
# 2118                 3.5               81.0                256.0
# 2124                 2.6               74.0               1348.0
# 2162                 1.5               66.0               1549.0
#
#       hour_bef_ozone  hour_bef_pm10  hour_bef_pm2.5
# 25             0.044           58.0            31.0
# 80             0.004           51.0            32.0
# 124            0.008           69.0            44.0
# 149            0.053          110.0            63.0
# 167            0.074           76.0            41.0
# ...              ...            ...             ...
# 2087           0.017           35.0            20.0
# 2094           0.039           26.0            13.0
# 2118           0.059           67.0            46.0
# 2124           0.014           32.0            24.0
# 2162           0.031           34.0            21.0
#
# [87 rows x 10 columns]

# %%
temp = df_bike[(df_bike['hour_bef_precipitation']==0) &  (df_bike['hour']==0)]
temp.isnull().sum()
# Out:
# id                        0
# hour                      0
# hour_bef_temperature      0
# hour_bef_precipitation    0
# hour_bef_windspeed        1
# hour_bef_humidity         0
# hour_bef_visibility       0
# hour_bef_ozone            0
# hour_bef_pm10             0
# hour_bef_pm2.5            1
# dtype: int64

# %%
temp_null = temp.isnull().sum().to_frame()
col = temp_null[temp_null[0]==1].index
col
# Out:
# Index(['hour_bef_windspeed', 'hour_bef_pm2.5'], dtype='object')

# %%
temp[temp['hour_bef_windspeed'].isnull()]
# Out:
#       id  hour  hour_bef_temperature  hour_bef_precipitation  \
# 376  570     0                  14.3                     0.0
#
#      hour_bef_windspeed  hour_bef_humidity  hour_bef_visibility  \
# 376                 NaN               49.0               2000.0
#
#      hour_bef_ozone  hour_bef_pm10  hour_bef_pm2.5
# 376           0.044           37.0            20.0

# %%
df_bike.loc[376,'hour_bef_windspeed']
# Out:
# nan

# %%
idx = temp[temp['hour_bef_windspeed'].isnull()].index
idx
# Out:
# Int64Index([376], dtype='int64')

# %%
new = temp['hour_bef_windspeed'].mean()
new
# Out:
# 1.9534883720930236

# %%
# df_bike.loc[idx,'hour_bef_windspeed'] = new

# %% [markdown]
# ## 시간 기준으로 채우기

# %%
df_bike = pd.concat([df_train.iloc[:,:-1],df_test], axis=0)
idx = df_bike[df_bike['hour_bef_temperature'].isnull()].index
df_bike = df_bike.drop(index = idx)
df_bike = df_bike.reset_index(drop=True)
df_bike.isnull().sum()
# Out:
# id                          0
# hour                        0
# hour_bef_temperature        0
# hour_bef_precipitation      0
# hour_bef_windspeed          7
# hour_bef_humidity           0
# hour_bef_visibility         0
# hour_bef_ozone            108
# hour_bef_pm10             124
# hour_bef_pm2.5            150
# dtype: int64

# %%
hour = [h for h in range(0,24)]
for h in hour:
    temp = df_bike[(df_bike['hour_bef_precipitation']==0) &  (df_bike['hour']== h)]
    
    # null 값이 있는 column 추출
    temp_null = temp.isnull().sum().to_frame()
    columns = temp_null[temp_null[0]==1].index
    print("시간: ", h)
    print("컬럼명: ",columns)
    print('nan값개수: ', temp.isnull().sum())
    
    # 인덱스 추출
    for col in columns:
        idx = temp[temp[col].isnull()].index
        new = temp[col].mean()
        
        df_bike.loc[idx,col] = new
# Out:
# 시간:  0
# 컬럼명:  Index(['hour_bef_windspeed', 'hour_bef_pm2.5'], dtype='object')
# nan값개수:  id                        0
# hour                      0
# hour_bef_temperature      0
# hour_bef_precipitation    0
# hour_bef_windspeed        1
# hour_bef_humidity         0
# hour_bef_visibility       0
# hour_bef_ozone            0
# hour_bef_pm10             0
# hour_bef_pm2.5            1
# dtype: int64
# 시간:  1
# 컬럼명:  Index(['hour_bef_windspeed'], dtype='object')
# nan값개수:  id                         0
# hour                       0
# hour_bef_temperature       0
# hour_bef_precipitation     0
# hour_bef_windspeed         1
# hour_bef_humidity          0
# hour_bef_visibility        0
# hour_bef_ozone            86
# hour_bef_pm10             86
# hour_bef_pm2.5            86
# dtype: int64
# 시간:  2
# 컬럼명:  Index(['hour_bef_windspeed', 'hour_bef_pm2.5'], dtype='object')
# nan값개수:  id                        0
# hour                      0
# hour_bef_temperature      0
# hour_bef_precipitation    0
# hour_bef_windspeed        1
# hour_bef_humidity         0
# hour_bef_visibility       0
# hour_bef_ozone            0
# hour_bef_pm10             0
# hour_bef_pm2.5            1
# dtype: int64
# 시간:  3
# 컬럼명:  Index(['hour_bef_windspeed', 'hour_bef_pm2.5'], dtype='object')
# nan값개수:  id                        0
# hour                      0
# hour_bef_temperature      0
# hour_bef_precipitation    0
# hour_bef_windspeed        1
# hour_bef_humidity         0
# hour_bef_visibility       0
# hour_bef_ozone            0
# hour_bef_pm10             0
# hour_bef_pm2.5            1
# dtype: int64
# 시간:  4
# 컬럼명:  Index(['hour_bef_pm2.5'], dtype='object')
# nan값개수:  id                        0
# hour                      0
# hour_bef_temperature      0
# hour_bef_precipitation    0
# hour_bef_windspeed        0
# hour_bef_humidity         0
# hour_bef_visibility       0
# hour_bef_ozone            0
# hour_bef_pm10             0
# hour_bef_pm2.5            1
# dtype: int64
# 시간:  5
# 컬럼명:  Index([], dtype='object')
# nan값개수:  id                        0
# hour                      0
# hour_bef_temperature      0
# hour_bef_precipitation    0
# hour_bef_windspeed        0
# hour_bef_humidity         0
# hour_bef_visibility       0
# hour_bef_ozone            0
# hour_bef_pm10             0
# hour_bef_pm2.5            2
# dtype: int64
# 시간:  6
# 컬럼명:  Index(['hour_bef_ozone', 'hour_bef_pm10'], dtype='object')
# nan값개수:  id                        0
# hour                      0
# hour_bef_temperature      0
# hour_bef_precipitation    0
# hour_bef_windspeed        0
# hour_bef_humidity         0
# hour_bef_visibility       0
# hour_bef_ozone            1
# hour_bef_pm10             1
# hour_bef_pm2.5            3
# dtype: int64
# 시간:  7
# 컬럼명:  Index(['hour_bef_ozone', 'hour_bef_pm10'], dtype='object')
# nan값개수:  id                        0
# hour                      0
# hour_bef_temperature      0
# hour_bef_precipitation    0
# hour_bef_windspeed        0
# hour_bef_humidity         0
# hour_bef_visibility       0
# hour_bef_ozone            1
# hour_bef_pm10             1
# hour_bef_pm2.5            2
# dtype: int64
# 시간:  8
# 컬럼명:  Index([], dtype='object')
# nan값개수:  id                        0
# hour                      0
# hour_bef_temperature      0
# hour_bef_precipitation    0
# hour_bef_windspeed        0
# hour_bef_humidity         0
# hour_bef_visibility       0
# hour_bef_ozone            0
# hour_bef_pm10             0
# hour_bef_pm2.5            2
# dtype: int64
# 시간:  9
# 컬럼명:  Index(['hour_bef_pm2.5'], dtype='object')
# nan값개수:  id                        0
# hour                      0
# hour_bef_temperature      0
# hour_bef_precipitation    0
# hour_bef_windspeed        0
# hour_bef_humidity         0
# hour_bef_visibility       0
# hour_bef_ozone            0
# hour_bef_pm10             0
# hour_bef_pm2.5            1
# dtype: int64
# 시간:  10
# 컬럼명:  Index(['hour_bef_ozone', 'hour_bef_pm10'], dtype='object')
# nan값개수:  id                        0
# hour                      0
# hour_bef_temperature      0
# hour_bef_precipitation    0
# hour_bef_windspeed        0
# hour_bef_humidity         0
# hour_bef_visibility       0
# hour_bef_ozone            1
# hour_bef_pm10             1
# hour_bef_pm2.5            3
# dtype: int64
# 시간:  11
# 컬럼명:  Index(['hour_bef_ozone', 'hour_bef_pm10'], dtype='object')
# nan값개수:  id                        0
# hour                      0
# hour_bef_temperature      0
# hour_bef_precipitation    0
# hour_bef_windspeed        0
# hour_bef_humidity         0
# hour_bef_visibility       0
# hour_bef_ozone            1
# hour_bef_pm10             1
# hour_bef_pm2.5            3
# dtype: int64
# 시간:  12
# 컬럼명:  Index(['hour_bef_windspeed', 'hour_bef_ozone'], dtype='object')
# nan값개수:  id                        0
# hour                      0
# hour_bef_temperature      0
# hour_bef_precipitation    0
# hour_bef_windspeed        1
# hour_bef_humidity         0
# hour_bef_visibility       0
# hour_bef_ozone            1
# hour_bef_pm10             3
# hour_bef_pm2.5            4
# dtype: int64
# 시간:  13
# 컬럼명:  Index(['hour_bef_windspeed'], dtype='object')
# nan값개수:  id                        0
# hour                      0
# hour_bef_temperature      0
# hour_bef_precipitation    0
# hour_bef_windspeed        1
# hour_bef_humidity         0
# hour_bef_visibility       0
# hour_bef_ozone            2
# hour_bef_pm10             5
# hour_bef_pm2.5            4
# dtype: int64
# 시간:  14
# 컬럼명:  Index(['hour_bef_pm10'], dtype='object')
# nan값개수:  id                        0
# hour                      0
# hour_bef_temperature      0
# hour_bef_precipitation    0
# hour_bef_windspeed        0
# hour_bef_humidity         0
# hour_bef_visibility       0
# hour_bef_ozone            2
# hour_bef_pm10             1
# hour_bef_pm2.5            3
# dtype: int64
# 시간:  15
# 컬럼명:  Index([], dtype='object')
# nan값개수:  id                        0
# hour                      0
# hour_bef_temperature      0
# hour_bef_precipitation    0
# hour_bef_windspeed        0
# hour_bef_humidity         0
# hour_bef_visibility       0
# hour_bef_ozone            2
# hour_bef_pm10             3
# hour_bef_pm2.5            4
# dtype: int64
# 시간:  16
# 컬럼명:  Index([], dtype='object')
# nan값개수:  id                        0
# hour                      0
# hour_bef_temperature      0
# hour_bef_precipitation    0
# hour_bef_windspeed        0
# hour_bef_humidity         0
# hour_bef_visibility       0
# hour_bef_ozone            3
# hour_bef_pm10             3
# hour_bef_pm2.5            4
# dtype: int64
# 시간:  17
# 컬럼명:  Index([], dtype='object')
# nan값개수:  id                        0
# hour                      0
# hour_bef_temperature      0
# hour_bef_precipitation    0
# hour_bef_windspeed        0
# hour_bef_humidity         0
# hour_bef_visibility       0
# hour_bef_ozone            2
# hour_bef_pm10             2
# hour_bef_pm2.5            4
# dtype: int64
# 시간:  18
# 컬럼명:  Index(['hour_bef_ozone'], dtype='object')
# nan값개수:  id                        0
# hour                      0
# hour_bef_temperature      0
# hour_bef_precipitation    0
# hour_bef_windspeed        0
# hour_bef_humidity         0
# hour_bef_visibility       0
# hour_bef_ozone            1
# hour_bef_pm10             5
# hour_bef_pm2.5            6
# dtype: int64
# 시간:  19
# 컬럼명:  Index([], dtype='object')
# nan값개수:  id                        0
# hour                      0
# hour_bef_temperature      0
# hour_bef_precipitation    0
# hour_bef_windspeed        0
# hour_bef_humidity         0
# hour_bef_visibility       0
# hour_bef_ozone            0
# hour_bef_pm10             3
# hour_bef_pm2.5            3
# dtype: int64
# 시간:  20
# 컬럼명:  Index(['hour_bef_windspeed', 'hour_bef_pm2.5'], dtype='object')
# nan값개수:  id                        0
# hour                      0
# hour_bef_temperature      0
# hour_bef_precipitation    0
# hour_bef_windspeed        1
# hour_bef_humidity         0
# hour_bef_visibility       0
# hour_bef_ozone            0
# hour_bef_pm10             2
# hour_bef_pm2.5            1
# dtype: int64
# 시간:  21
# 컬럼명:  Index(['hour_bef_pm2.5'], dtype='object')
# nan값개수:  id                        0
# hour                      0
# hour_bef_temperature      0
# hour_bef_precipitation    0
# hour_bef_windspeed        0
# hour_bef_humidity         0
# hour_bef_visibility       0
# hour_bef_ozone            0
# hour_bef_pm10             0
# hour_bef_pm2.5            1
# dtype: int64
# 시간:  22
# 컬럼명:  Index(['hour_bef_pm2.5'], dtype='object')
# nan값개수:  id                        0
# hour                      0
# hour_bef_temperature      0
# hour_bef_precipitation    0
# hour_bef_windspeed        0
# hour_bef_humidity         0
# hour_bef_visibility       0
# hour_bef_ozone            0
# hour_bef_pm10             0
# hour_bef_pm2.5            1
# dtype: int64
# 시간:  23
# 컬럼명:  Index(['hour_bef_pm2.5'], dtype='object')
# nan값개수:  id                        0
# hour                      0
# hour_bef_temperature      0
# hour_bef_precipitation    0
# hour_bef_windspeed        0
# hour_bef_humidity         0
# hour_bef_visibility       0
# hour_bef_ozone            0
# hour_bef_pm10             0
# hour_bef_pm2.5            1
# dtype: int64

# %%
 df_bike.isnull().sum()
# Out:
# id                          0
# hour                        0
# hour_bef_temperature        0
# hour_bef_precipitation      0
# hour_bef_windspeed          0
# hour_bef_humidity           0
# hour_bef_visibility         0
# hour_bef_ozone            102
# hour_bef_pm10             119
# hour_bef_pm2.5            141
# dtype: int64

# %%
temp[temp[col].isnull()].index
# Out:
# Int64Index([819], dtype='int64')

# %%
df_bike.loc[idx,col]
# Out:
# 819    28.551724
# Name: hour_bef_pm2.5, dtype: float64
