# %% [markdown]
# # Titanic_practice

# %% [markdown]
# ## 처음시도

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import missingno as msno

import warnings
warnings.filterwarnings('ignore')

plt.style.use('seaborn')
sns.set(font_scale=2.5)

# %%
df = pd.read_csv('../data/train.csv')
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.shape
# Out:
# (891, 12)

# %%
df.nunique()
# Out:
# PassengerId    891
# Survived         2
# Pclass           3
# Name           891
# Sex              2
# Age             88
# SibSp            7
# Parch            7
# Ticket         681
# Fare           248
# Cabin          147
# Embarked         3
# dtype: int64

# %%
# null값 age:117, Embarked:2  
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
# Nan값 시각화
msno.matrix(df)
# Out:
# <AxesSubplot:>

# %%
# SibSp, Parch, Fare 데이터 이해 부족
# Age, Fare 데이터의 카테고리가 너무 많음
# Name,Ticket 사용 x

# %% [markdown]
# ## 고려할 사항
# * 'Age'의 Nan값을 어떻게 처리할 것인가
# * 'Age', 'Fare' 데이터를 그대로 사용할 것인가
# * 'SibSp','Parch' 모르는 성질의 데이터를 어떻게 할 것인가

# %% [markdown]
# ### Survived 값에 따라 나누기

# %%
df1 = df.drop(columns = ['Name','Ticket'])
df1.head()
# Out:
#    PassengerId  Survived  Pclass     Sex   Age  SibSp  Parch     Fare Cabin  \
# 0            1         0       3    male  22.0      1      0   7.2500   NaN
# 1            2         1       1  female  38.0      1      0  71.2833   C85
# 2            3         1       3  female  26.0      0      0   7.9250   NaN
# 3            4         1       1  female  35.0      1      0  53.1000  C123
# 4            5         0       3    male  35.0      0      0   8.0500   NaN
#
#   Embarked
# 0        S
# 1        C
# 2        S
# 3        S
# 4        S

# %%
cond1 = df1['Survived'] ==0
cond2 = df1['Survived'] ==1

df1[cond1].head()
# Out:
#    PassengerId  Survived  Pclass   Sex   Age  SibSp  Parch     Fare Cabin  \
# 0            1         0       3  male  22.0      1      0   7.2500   NaN
# 4            5         0       3  male  35.0      0      0   8.0500   NaN
# 5            6         0       3  male   NaN      0      0   8.4583   NaN
# 6            7         0       1  male  54.0      0      0  51.8625   E46
# 7            8         0       3  male   2.0      3      1  21.0750   NaN
#
#   Embarked
# 0        S
# 4        S
# 5        Q
# 6        S
# 7        S

# %%
def show_column_hist_by_target(df, column):
    cond1 = df['Survived']==0
    cond2 = df['Survived']==1
    
    fig, axs = plt.subplots(figsize=(12,4),nrows=1,ncols=2,squeeze=False) # squeeze?
    
    sns.violinplot(x='Survived', y=df[column], data=df, ax=axs[0][0])
    sns.distplot(df[cond1][column], ax=axs[0][1])
    sns.distplot(df[cond2][column], ax=axs[0][1])

# %% [markdown]
# ### 'Age' 열 관찰하기

# %%
df['Age'].describe()
# Out:
# count    714.000000
# mean      29.699118
# std       14.526497
# min        0.420000
# 25%       20.125000
# 50%       28.000000
# 75%       38.000000
# max       80.000000
# Name: Age, dtype: float64

# %%
# 나이가 0보다 작은 데이터들 존재
df['Age'].sort_values()
# .value_counts()
# Out:
# 803    0.42
# 755    0.67
# 644    0.75
# 469    0.75
# 78     0.83
#        ...
# 859     NaN
# 863     NaN
# 868     NaN
# 878     NaN
# 888     NaN
# Name: Age, Length: 891, dtype: float64

# %%
# 의미있어보임
df[df['Age']<=1]
# Out:
#      PassengerId  Survived  Pclass                             Name     Sex  \
# 78            79         1       2    Caldwell, Master. Alden Gates    male
# 164          165         0       3     Panula, Master. Eino Viljami    male
# 172          173         1       3     Johnson, Miss. Eleanor Ileen  female
# 183          184         1       2        Becker, Master. Richard F    male
# 305          306         1       1   Allison, Master. Hudson Trevor    male
# 381          382         1       3      Nakid, Miss. Maria ("Mary")  female
# 386          387         0       3  Goodwin, Master. Sidney Leonard    male
# 469          470         1       3    Baclini, Miss. Helene Barbara  female
# 644          645         1       3           Baclini, Miss. Eugenie  female
# 755          756         1       2        Hamalainen, Master. Viljo    male
# 788          789         1       3       Dean, Master. Bertram Vere    male
# ...

# %%
plt.figure(figsize=(10,10))

# %%
df['Age'].hist(bins=50)
# Out:
# <AxesSubplot:>

# %%
sns.distplot(df['Age'].dropna())
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Density'>

# %%
# boxplot
plt.boxplot(df['Age'].dropna())
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x191027dc700>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x191027dc7c0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x191027dcbb0>],
#  'medians': [<matplotlib.lines.Line2D at 0x191001864c0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x19100186820>],
#  'means': []}

# %%
sns.boxplot(df['Age'].dropna())
# Out:
# <AxesSubplot:xlabel='Age'>

# %% [markdown]
# #### target 에 따라 나눠보기

# %%
sns.violinplot(x='Survived',y='Age', data=df1 )
# Out:
# <AxesSubplot:xlabel='Survived', ylabel='Age'>

# %%
show_column_hist_by_target(df1,'Age')

# %% [markdown]
# ### Fare 살펴보기

# %%
df['Fare'].describe()
# Out:
# count    891.000000
# mean      32.204208
# std       49.693429
# min        0.000000
# 25%        7.910400
# 50%       14.454200
# 75%       31.000000
# max      512.329200
# Name: Fare, dtype: float64

# %%
df['Fare'].hist(bins=50)
# Out:
# <AxesSubplot:>

# %%
df1['Fare'].describe()
# Out:
# count    891.000000
# mean      32.204208
# std       49.693429
# min        0.000000
# 25%        7.910400
# 50%       14.454200
# 75%       31.000000
# max      512.329200
# Name: Fare, dtype: float64

# %%
show_column_hist_by_target(df1,'Fare')

# %% [markdown]
# ## 모르는데이터 1. SibSp

# %%
df1['SibSp'].unique()
# Out:
# array([1, 0, 3, 4, 2, 5, 8], dtype=int64)

# %%
show_column_hist_by_target(df1,'SibSp')

# %%
show_column_hist_by_target(df1,'Parch')
